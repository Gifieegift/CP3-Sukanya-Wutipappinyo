# %%
def add_number(a,b):
    sum = a+b 
    print(sum)
    
def sub_number(a,b):
    sub = a-b
    print(sub)
    
def mul_number(a,b):
    mul = a*b
    print(mul)  
    
def div_number(a,b):
    div = a/b
    print(div)
