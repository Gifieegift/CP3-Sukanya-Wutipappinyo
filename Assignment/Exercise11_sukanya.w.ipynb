# %%
height = int(input("Enter a heightnum: ")) 
for row in range(height): 
    for space in range(height - row - 1):
        print(" " ,end ="")
    for col in range(row+1):
        print("* ",end="")
    print()
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *
