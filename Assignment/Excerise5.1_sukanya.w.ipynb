# %%
first_num = int(input("Please inpisy 1st number(int): "))
second_num = int(input("Please inpisy 2nd number(int): "))
print("-------------------result----------------------")
print(first_num,"+",second_num,"=", first_num+second_num)
print(first_num,"-",second_num,"=", first_num-second_num)
print(first_num,"*",second_num,"=", first_num*second_num)
print(first_num,"/",second_num,"=", first_num/second_num)
# Out:
# -------------------result----------------------
# 10 + 6 = 16
# 10 - 6 = 4
# 10 * 6 = 60
# 10 / 6 = 1.6666666666666667
