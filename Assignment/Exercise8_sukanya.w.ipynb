# %%
username = input('username: ')
password = input('pass : ')
if username == 'abc' and password == "123" :
    print('login')
    print('----welcome to Gift shop----')
    print('----Our menu----')
    print(1,'Apple', 10, 'THB/Pcs')
    print(2,'Banana', 15, 'THB/Pcs')
    print(3,'Orange', 20, 'THB/Pcs')
    total = 0
    while True:
        Order = str(input('Would you like to order(Y/N) : '))
        if Order.upper() == 'Y':
            Menu = int(input('Please select menu : '))
            QTY = int(input('Please input quantity : '))
            if Menu == 1:
                price= QTY*10
            elif Menu == 2:
                price= QTY*15
            elif Menu == 3:
                price = QTY*20
            else : 
                print("Menu not found, please try again")
                continue
            
            total = price + total
            print(f'Total price : {total} THB')
        elif Order.upper() == 'N':
            break
        else :
            print("Invalid input, please try again")
            continue
# Out:
# login
# ----welcome to Gift shop----
# ----Our menu----
# 1 Apple 10 THB/Pcs
# 2 Banana 15 THB/Pcs
# 3 Orange 20 THB/Pcs
# Total price : 70 THB
# Menu not found, please try again
# Invalid input, please try again
# Invalid input, please try again
# Invalid input, please try again
# Total price : 250 THB
