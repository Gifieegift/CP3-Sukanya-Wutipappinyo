# %%
class Customer :
    name = ""
    lastneme = ""
    age = 0 
    def Addcart(self):
        print(f"Add to {self.name} {self.lastname} 's cart")

# %%
#create object
customer1 = Customer()
customer1.name = "Gift"
customer1.lastname = "Goose"
customer1.age = 30
customer1.Addcart()
# Out:
# Add to Gift Goose 's cart

# %%
#create other object
customer2 = Customer()
customer2.name = "Graph"
customer2.lastname = "Goose"
customer2.age = 32
customer2.Addcart()
# Out:
# Add to Graph Goose 's cart

# %%
#create other object
customer3 = Customer()
customer3.name = "Golf"
customer3.lastname = "Goose"
customer3.age = 28
customer3.Addcart()
# Out:
# Add to Golf Goose 's cart
